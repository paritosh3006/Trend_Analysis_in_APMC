# %%
import seaborn as sns, numpy as np
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Sony\Desktop\CMO_MSP_Mandi.csv")

# %%
t = sns.boxplot(df1['msprice'], whis = 1.5)
bplot = sns.swarmplot(df1['msprice'], color='black', alpha = 0.75)
